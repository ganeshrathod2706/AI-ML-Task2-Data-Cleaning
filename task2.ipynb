# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("Task 2 Starting Successfully")
# Out:
# Task 2 Starting Successfully

# %%
df = pd.read_csv("dataset.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
#Age Fill Using Mean
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
print(df['Age'].isnull().sum())
# Out:
# 0

# %%
#Embarked Fill Using Mode
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
print(df['Embarked'].isnull().sum())
# Out:
# 0

# %%
print("Cabin Column Deleted Successfully")
df.drop('Cabin', axis=1, inplace=True)
# Out:
# Cabin Column Deleted Successfully

# %%
print("Final Checking:")
print(df.isnull().sum())
# Out:
# Final Checking:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#After Cleaning Data
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
#Save Clean Dataset
df.to_csv("cleaned_dataset.csv", index=False)

print("Cleaned Dataset Saved Successfully")
# Out:
# Cleaned Dataset Saved Successfully

# %% [markdown]
# # Summary
#
# 1. Checked missing values
# 2. Visualized missing data using heatmap
# 3. Filled missing Age values using mean
# 4. Filled Embarked using mode
# 5. Dropped Cabin column
# 6. Saved cleaned dataset
